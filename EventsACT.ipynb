# %%
import requests
import json
from datetime import date,datetime
from dateutil.relativedelta import relativedelta

# %%
http_proxy  = "http://localhost:3128/"
https_proxy = "http://localhost:3128/"


proxyDict = {
              "http"  : http_proxy,
              "https" : https_proxy
            }

# %%
currentday= datetime.today().strftime('%Y-%m-%d')
print(currentday)
six_months = (date.today() + relativedelta(months=+6)).strftime('%Y-%m-%d')
print(six_months)
# Out:
# 2020-10-22
# 2021-04-22

# %%
producturl = "https://atlas.atdw-online.com.au/api/atlas/product?key=ATDW001&out=json&productId="
event_url ="https://atlas.atdw-online.com.au/api/atlas/products?key=ATDW001&cats=ATTRACTION&st=ACT&term=markets&out=JSON&size=200&start="+currentday+"&end="+six_months

# %%
response = requests.get(event_url, proxies=proxyDict, verify=False)
# Out:
# /home/mapr/envs/test_venv/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
response.json()
# Out:
# {'numberOfResults': 32,
#  'products': [{'addresses': [{'address_line': '36 Mildura Street',
#      'address_line2': '',
#      'address_type': 'PHYSICAL',
#      'area': ['Canberra'],
#      'city': 'Fyshwick',
#      'country': 'Australia',
#      'postcode': '2609',
#      'region': ['Canberra Region'],
#      'state': 'ACT'}],
#    'boundary': '-35.3236596,149.15621650000003',
#    'owningOrganisationId': '56b1ec6244feca3df2e3486f',
#    'owningOrganisationName': 'Fyshwick Fresh Food Market',
#    'owningOrganisationNumber': 'ACTAB13',
#    'productCategoryId': 'ATTRACTION',
#    'productDescription': 'Bringing an entirely new wing of shopping opportunities, the Niche Markets add a new dimension to the Fyshwick Markets experience and provides even more reasons for people to come to Fyshwick.\n\nThe Niche Markets is home to local, artisan traders and holds everything from fashion and jewellery to homewares, flowers, food and more.\r\n\r\n',
# ...
